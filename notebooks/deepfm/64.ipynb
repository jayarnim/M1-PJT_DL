# %%
MODEL_CLS = "deepfm"
EMBEDDING_DIM = 64
PATH_WORK_DIR = "../.."

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\REPO\PROJECT\M1-PJT_DL

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Packages

# %%
import pandas as pd
from ctr import config, featuremap, datamodule, trainer, evaluator, utils
import fm

# %%
PATH = f"./config/{MODEL_CLS}.yaml"
cfg = config.build_config(PATH)

# %%
utils.seed.main(cfg.seed)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Load Data

# %%
PATH = "./data/criteo.csv"
df = pd.read_csv(PATH)

# %%
y_col = "label"
X_col = df.columns.difference([y_col])

# %%
NUMERIC_COL = [
    col 
    for col in X_col 
    if "I" in col
]

CATEGORICAL_COL = [
    col 
    for col in X_col 
    if "C" in col
]

# %%
y = df[y_col]
X = df[X_col]

# %% [markdown]
# # Data Preparation

# %%
kwargs = dict(
    X=X,
    y=y,
    cfg=cfg.datamodule,
    scaling=NUMERIC_COL,
)

dataloaders = datamodule.build_datamodule(**kwargs)

# %%
kwargs = dict(
    X=X,
    cat_cols=CATEGORICAL_COL,
    num_cols=NUMERIC_COL,
)

feature_map = featuremap.build_feature_map(**kwargs)

# %% [markdown]
# # Modeling

# %%
NUM_FEATURES = 39

i = 0
units = list()

while True:
    UNIT = (2**i)
    if EMBEDDING_DIM*NUM_FEATURES < UNIT:
        break
    else:
        units.append(UNIT)
        i+=1

HIDDEN_DIM = units[:-4:-1]

# %%
kwargs = dict(
    **cfg.model.params,
    embedding_dim=EMBEDDING_DIM,
    hidden_dim=HIDDEN_DIM,
    feature_map=feature_map,
)

model = fm.deepfm.DeepFactorizationMachine(**kwargs)

# %% [markdown]
# # Training

# %%
kwargs = dict(
    model=model,
    cfg=cfg.trainer,
)

opt = trainer.build_trainer(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
)

records = opt.fit(**kwargs)
# Out:
# BEST EPOCH: 1
# BEST SCORE: 0.7754

# %%
SUPTITLE = f"DeepFM Training History (Emb: {EMBEDDING_DIM})"
TRN_SCORE = "BCE"
VAL_SCORE = "AUROC"
FIGSIZE = (7,3)

kwargs = dict(
    records=records,
    suptitle=SUPTITLE,
    trn=TRN_SCORE,
    val=VAL_SCORE,
    figsize=FIGSIZE,
)

utils.visualizer.main(**kwargs)

# %% [markdown]
# # Evaluation

# %%
kwargs = dict(
    model=model, 
    threshold=records["threshold"],
)

msr = evaluator.build_evaluator(**kwargs)

# %%
result, metrics_sheet = msr(dataloaders["tst"])
# Out:
# TST: 100%|██████████| 196/196 [00:02<00:00, 86.05it/s]

# %%
metrics_sheet
# Out:
#    threshold  accuracy  precision    recall        f1     auroc   logloss
# 0   0.266648   0.69701   0.443786  0.720441  0.549243  0.776374  0.470928

# %% [markdown]
# # Save

# %%
PATH = f'./result/score/{MODEL_CLS}_{EMBEDDING_DIM}.csv'

kwargs = dict(
    path_or_buf=PATH,
    index=False,
)

result.to_csv(**kwargs)

# %%
PATH = f'./result/metric/{MODEL_CLS}_{EMBEDDING_DIM}.csv'

kwargs = dict(
    path_or_buf=PATH,
    index=False,
)

metrics_sheet.to_csv(**kwargs)

# %%
PATH = f'./checkpoints/{MODEL_CLS}_{EMBEDDING_DIM}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

utils.checkpointer.save(**kwargs)
