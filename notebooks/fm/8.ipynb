# %%
MODEL_CLS = "fm"
EMBEDDING_DIM = 8
PATH_WORK_DIR = "../.."

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\REPO\PROJECT\M1-PJT_DL

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Packages

# %%
import pandas as pd
from ctr import config, datamodule, featuremap, trainer, evaluator, utils
import fm

# %%
PATH = f"./config/{MODEL_CLS}.yaml"
cfg = config.build_config(PATH)

# %%
utils.seed.main(cfg.seed)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Load Data

# %%
PATH = "./data/criteo.csv"
df = pd.read_csv(PATH)

# %%
y_col = "label"
X_col = df.columns.difference([y_col])

# %%
NUMERIC_COL = [
    col 
    for col in X_col 
    if "I" in col
]

CATEGORICAL_COL = [
    col 
    for col in X_col 
    if "C" in col
]

# %%
y = df[y_col]
X = df[X_col]

# %% [markdown]
# # Data Preparation

# %%
kwargs = dict(
    X=X,
    y=y,
    cfg=cfg.datamodule,
    scaling=NUMERIC_COL,
)

dataloaders = datamodule.build_datamodule(**kwargs)

# %%
kwargs = dict(
    X=X,
    cat_cols=CATEGORICAL_COL,
    num_cols=NUMERIC_COL,
)

feature_map = featuremap.build_feature_map(**kwargs)

# %% [markdown]
# # Modeling

# %%
kwargs = dict(
    **cfg.model.params,
    embedding_dim=EMBEDDING_DIM,
    feature_map=feature_map,
)

model = fm.fm.FactorizationMachine(**kwargs)

# %% [markdown]
# # Training

# %%
kwargs = dict(
    model=model,
    cfg=cfg.trainer,
)

opt = trainer.build_trainer(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
)

records = opt.fit(**kwargs)
# Out:
# BEST EPOCH: 7
# BEST SCORE: 0.7714

# %%
SUPTITLE = f"FM Training History (Emb: {EMBEDDING_DIM})"
TRN_SCORE = "BCE"
VAL_SCORE = "AUROC"
FIGSIZE = (7,3)

kwargs = dict(
    records=records,
    suptitle=SUPTITLE,
    trn=TRN_SCORE,
    val=VAL_SCORE,
    figsize=FIGSIZE,
)

utils.visualizer.main(**kwargs)

# %% [markdown]
# # Evaluation

# %%
kwargs = dict(
    model=model, 
    threshold=records["threshold"],
)

msr = evaluator.build_evaluator(**kwargs)

# %%
result, metrics_sheet = msr(dataloaders["tst"])
# Out:
# TST: 100%|██████████| 196/196 [00:02<00:00, 83.59it/s]

# %%
metrics_sheet
# Out:
#    threshold  accuracy  precision    recall        f1     auroc   logloss
# 0   0.262666   0.70647   0.452075  0.686701  0.545218  0.771557  0.475026

# %% [markdown]
# # Save

# %%
PATH = f'./result/score/{MODEL_CLS}_{EMBEDDING_DIM}.csv'

kwargs = dict(
    path_or_buf=PATH,
    index=False,
)

result.to_csv(**kwargs)

# %%
PATH = f'./result/metric/{MODEL_CLS}_{EMBEDDING_DIM}.csv'

kwargs = dict(
    path_or_buf=PATH,
    index=False,
)

metrics_sheet.to_csv(**kwargs)

# %%
PATH = f'./checkpoints/{MODEL_CLS}_{EMBEDDING_DIM}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

utils.checkpointer.save(**kwargs)
